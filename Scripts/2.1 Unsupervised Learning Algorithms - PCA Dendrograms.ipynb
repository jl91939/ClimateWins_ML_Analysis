# %% [markdown]
# # Importing Libraries + Setting Path.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import os
import operator
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans
from matplotlib.pyplot import figure
from scipy.cluster.hierarchy import dendrogram, linkage, fcluster
from scipy.spatial.distance import pdist

path = r'C:\Users\Chaot\Python stuff\07 - Basics of Machine Learning for Analysts'

# %% [markdown]
# # Importing Dataframes.

# %%
pca_df = pd.read_csv(os.path.join(path, 'Data Brief + Data Sets', 'PCA_df.csv'))
pca_df
# Out:
#          PCA_1     PCA_2
# 0   -12.303670  3.984468
# 1   -11.275915  4.828021
# 2   -10.795703  3.593919
# 3    -9.744379  2.305812
# 4   -10.362477  3.885228
# ..         ...       ...
# 361 -11.870624 -8.194647
# 362 -12.631110 -7.532162
# 363 -13.192649 -6.635848
# 364 -13.195805 -3.368171
# 365 -13.316898  1.617345
#
# [366 rows x 2 columns]

# %% [markdown]
# # Dendrogram - Single.

# %%
distance_single = linkage(pca_df,method='single')
plt.figure(figsize=(20,6))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle('Dendrogram Single Method - PCA',fontsize=18)
plt.savefig(os.path.join(path, 'Unsupervised', '2.1_dendrogram_single_pca.png'), bbox_inches='tight')
plt.show()

# %% [markdown]
# # Dendrogram - Complete.

# %%
distance_single = linkage(pca_df,method='complete')
plt.figure(figsize=(20,6))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle('Dendrogram Complete Method - PCA',fontsize=18)
plt.savefig(os.path.join(path, 'Unsupervised', '2.1_dendrogram_complete_pca.png'), bbox_inches='tight')
plt.show()

# %% [markdown]
# # Dendrogram - Average.

# %%
distance_single = linkage(pca_df,method='average')
plt.figure(figsize=(20,6))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle('Dendrogram Average Method - PCA',fontsize=18)
plt.savefig(os.path.join(path, 'Unsupervised', '2.1_dendrogram_average_pca.png'), bbox_inches='tight')
plt.show()

# %% [markdown]
# # Dendrogram - Ward.

# %%
distance_single = linkage(pca_df,method='ward')
plt.figure(figsize=(20,6))
dendrogram(distance_single, leaf_rotation=90)
plt.xlabel('Index')
plt.ylabel('Distance')
plt.suptitle('Dendrogram Ward Method - PCA',fontsize=18)
plt.savefig(os.path.join(path, 'Unsupervised', '2.1_dendrogram_ward_pca.png'), bbox_inches='tight')
plt.show()

# %%
pca_df
# Out:
#          PCA_1     PCA_2
# 0   -12.303670  3.984468
# 1   -11.275915  4.828021
# 2   -10.795703  3.593919
# 3    -9.744379  2.305812
# 4   -10.362477  3.885228
# ..         ...       ...
# 361 -11.870624 -8.194647
# 362 -12.631110 -7.532162
# 363 -13.192649 -6.635848
# 364 -13.195805 -3.368171
# 365 -13.316898  1.617345
#
# [366 rows x 2 columns]

# %%
kmeans = KMeans(n_clusters=2, random_state=42)
pca_df['kmeans_cluster'] = kmeans.fit_predict(pca_df)
pca_df
# Out:
# G:\Anaconda\Lib\site-packages\sklearn\cluster\_kmeans.py:1446: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
#          PCA_1     PCA_2  kmeans_cluster
# 0   -12.303670  3.984468               1
# 1   -11.275915  4.828021               1
# 2   -10.795703  3.593919               1
# 3    -9.744379  2.305812               1
# 4   -10.362477  3.885228               1
# ..         ...       ...             ...
# 361 -11.870624 -8.194647               1
# 362 -12.631110 -7.532162               1
# 363 -13.192649 -6.635848               1
# 364 -13.195805 -3.368171               1
# 365 -13.316898  1.617345               1
#
# [366 rows x 3 columns]

# %%
pca_df['label'] = np.random.choice(['BASEL_wind_speed', 'BASEL_cloud_cover'], size=len(pca_df))
pca_df
# Out:
#          PCA_1     PCA_2  kmeans_cluster              label
# 0   -12.303670  3.984468               1   BASEL_wind_speed
# 1   -11.275915  4.828021               1   BASEL_wind_speed
# 2   -10.795703  3.593919               1   BASEL_wind_speed
# 3    -9.744379  2.305812               1   BASEL_wind_speed
# 4   -10.362477  3.885228               1  BASEL_cloud_cover
# ..         ...       ...             ...                ...
# 361 -11.870624 -8.194647               1   BASEL_wind_speed
# 362 -12.631110 -7.532162               1  BASEL_cloud_cover
# 363 -13.192649 -6.635848               1  BASEL_cloud_cover
# 364 -13.195805 -3.368171               1  BASEL_cloud_cover
# 365 -13.316898  1.617345               1   BASEL_wind_speed
#
# [366 rows x 4 columns]

# %%
pca_df.to_csv(os.path.join(path, 'Data Brief + Data Sets', 'pca_df_cluster_label.csv'))

# %%
sns.set_theme()
plt.figure(figsize=(20, 12))
g = sns.catplot(x="PCA_1", y="PCA_2", palette='Set1', hue="label", data=pca_df)
plt.xticks([0, 61, 132, 193, 254, 315, 366], rotation=45)
# Out:
# G:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# G:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# G:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# ([<matplotlib.axis.XTick at 0x2ab40041cd0>,
# ...
#  [Text(0, 0, '-14.645842115747024'),
#   Text(61, 0, '-7.710570895798154'),
#   Text(132, 0, '-4.931719802932345'),
#   Text(193, 0, '0.1804801720090184'),
#   Text(254, 0, '5.335175082652863'),
#   Text(315, 0, '9.648045922986809'),
#   Text(366, 0, '')])

# %%
sns.set_theme()
plt.figure(figsize=(20, 12))
g = sns.catplot(x="PCA_1", y="PCA_2", palette='Set1', hue="kmeans_cluster", data=pca_df)
plt.xticks([0, 61, 132, 193, 254, 315, 366], rotation=45)
# Out:
# G:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# G:\Anaconda\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# G:\Anaconda\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
# ([<matplotlib.axis.XTick at 0x2ab4214f8d0>,
# ...
#  [Text(0, 0, '-14.645842115747024'),
#   Text(61, 0, '-7.710570895798154'),
#   Text(132, 0, '-4.931719802932345'),
#   Text(193, 0, '0.1804801720090184'),
#   Text(254, 0, '5.335175082652863'),
#   Text(315, 0, '9.648045922986809'),
#   Text(366, 0, '')])
